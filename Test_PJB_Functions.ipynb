# %%
from my_functions import *
# Parameters
#data = np.random.random(40)*10
data = {i:np.random.random() for i in range(20)}

graph = marimekko(data,cmap='Spectral', title = 'Marimekko Graph', text=True, fontsize=15, numbers=False)
graph.savefig('Marimekko.pdf', bbox_inches='tight')
